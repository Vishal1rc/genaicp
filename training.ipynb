# %%
# !unzip /content/sample_data/archive.zip -d/content/sample_data/monet/monet_tfrec
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/sample_data/monet/monet_tfrec/images/62764_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62765_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62766_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62767_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62768_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62769_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6276_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62770_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62771_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62772_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62773_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62774_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62775_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62776_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62777_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62778_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62779_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6277_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62780_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62781_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62782_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62783_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62784_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62785_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62786_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62787_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62788_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62789_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6278_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62790_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62791_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62792_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62793_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62794_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62795_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62796_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62797_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62798_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62799_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6279_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/627_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62800_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62801_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62802_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62803_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62804_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62805_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62806_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62807_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62808_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62809_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6280_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62810_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62811_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62812_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62813_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62814_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62815_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62816_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62817_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62818_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62819_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6281_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62820_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62821_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62822_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62824_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62825_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62826_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62827_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62828_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62829_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6282_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62830_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62831_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62832_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62833_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62834_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62835_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62836_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62837_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62838_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62839_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6283_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62840_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62841_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62842_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62843_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62844_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62845_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62846_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62847_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62848_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62849_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6284_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62850_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62851_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62852_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62853_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62854_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62855_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62856_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62857_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62858_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62859_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6285_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62860_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62861_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62862_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62863_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62864_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62865_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62866_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62867_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62868_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62869_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6286_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62870_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62871_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62872_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62873_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62874_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62875_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62876_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62877_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62878_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62879_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6287_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62880_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62881_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62882_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62883_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62884_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62885_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62886_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62887_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62888_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62889_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6288_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62890_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62891_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62892_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62893_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62894_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62895_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62896_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62897_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62898_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62899_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6289_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/628_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62900_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62901_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62902_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62903_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62904_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62905_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62906_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62907_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62908_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62909_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6290_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62910_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62911_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62912_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62913_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62914_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62915_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62916_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62917_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62918_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62919_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6291_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62920_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62921_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62922_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62923_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62924_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62925_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62926_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62927_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62928_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62929_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6292_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62930_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62931_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62932_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62933_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62934_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62935_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62936_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62937_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62938_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62939_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6293_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62940_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62941_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62942_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62943_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62944_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62945_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62946_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62947_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62948_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62949_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6294_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62950_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62951_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62952_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62953_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62954_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62955_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62956_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62957_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62958_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62959_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6295_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62960_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62961_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62962_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62963_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62964_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62965_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62966_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62967_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62968_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62969_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6296_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62970_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62971_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62972_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62973_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62974_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62975_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62976_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62977_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62978_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62979_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6297_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62980_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62981_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62982_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62983_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62984_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62985_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62986_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62987_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62988_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62989_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6298_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62990_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62991_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62992_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62993_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62994_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62995_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62996_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62997_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62998_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62999_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6299_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/629_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/62_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63000_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63001_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63002_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63003_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63004_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63005_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63006_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63007_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63008_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63009_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6300_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63010_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63011_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63012_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63013_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63014_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63015_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63016_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63017_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63018_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63019_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6301_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63020_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63021_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63022_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63023_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63024_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63025_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63026_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63027_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63028_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63029_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6302_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63030_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63031_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63032_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63033_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63034_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63035_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63036_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63037_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63038_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63039_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6303_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63040_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63041_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63042_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63043_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63044_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63045_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63046_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63047_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63048_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63049_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6304_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63050_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63051_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63052_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63053_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63054_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63055_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63056_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63057_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63058_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63059_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6305_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63060_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63061_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63062_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63063_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63064_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63065_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63066_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63067_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63068_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63069_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6306_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63070_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63071_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63072_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63073_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63074_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63075_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63076_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63077_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63078_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63079_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6307_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63080_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63081_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63082_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63083_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63084_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63085_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63086_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63087_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63088_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63089_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6308_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63090_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63091_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63092_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63093_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63094_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63095_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63096_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63097_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63098_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63099_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6309_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/630_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63100_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63101_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63102_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63103_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63104_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63105_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63106_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63107_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63108_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63109_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6310_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63110_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63111_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63112_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63113_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63114_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63115_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63116_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63117_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63118_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63119_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6311_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63120_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63121_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63122_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63123_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63124_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63125_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63126_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63127_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63128_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63129_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6312_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63130_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63131_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63132_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63133_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63134_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63135_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63136_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63137_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63138_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63139_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6313_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63140_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63141_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63142_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63143_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63144_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63145_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63146_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63147_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63148_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63149_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6314_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63150_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63151_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63152_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63153_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63154_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63155_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63156_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63157_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63158_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63159_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6315_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63160_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63161_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63162_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63163_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63164_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63165_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63166_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63167_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63168_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63169_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6316_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63170_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63171_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63172_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63173_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63174_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63175_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63176_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63177_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63178_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63179_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6317_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63180_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63181_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63182_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63183_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63184_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63185_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63186_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63187_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63188_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63189_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6318_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63190_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63191_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63192_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63193_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63194_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63195_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63196_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63197_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63198_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63199_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6319_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/631_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63200_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63201_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63202_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63203_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63204_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63205_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63206_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63207_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63208_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63209_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6320_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63210_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63211_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63212_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63213_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63214_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63215_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63216_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63217_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63218_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63219_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6321_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63220_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63221_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63222_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63223_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63224_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63225_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63226_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63227_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63228_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63229_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6322_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63230_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63231_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63232_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63233_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63234_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63235_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63236_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63237_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63238_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63239_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6323_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63240_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63241_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63242_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63243_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63244_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63245_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63246_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63247_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63248_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63249_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6324_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63250_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63251_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63252_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63253_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63254_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63255_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63256_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63257_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63258_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63259_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6325_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63260_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63261_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63262_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63263_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63264_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63265_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63266_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63267_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63268_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63269_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6326_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63270_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63271_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63272_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63273_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63274_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63275_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63276_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63277_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63278_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63279_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6327_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63280_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63281_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63282_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63283_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63284_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63285_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63286_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63287_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63288_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63289_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6328_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63290_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63291_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63292_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63293_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63294_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63295_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63296_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63297_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63298_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63299_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6329_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/632_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63300_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63301_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63302_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63303_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63304_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63305_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63306_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63307_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63308_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63309_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6330_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63310_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63311_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63312_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63313_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63314_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63315_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63316_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63317_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63318_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63319_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6331_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63320_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63321_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63322_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63323_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63324_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63325_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63326_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63327_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63328_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63329_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/6332_2003.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63330_2019.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/63331_2019.jpg
# ...
#   inflating: /content/sample_data/monet/monet_tfrec/images/980_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9810_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9811_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9812_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9813_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9814_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9815_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9816_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9817_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9818_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9819_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/981_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9820_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9821_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9822_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9823_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9824_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9825_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9826_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9827_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9828_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9829_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/982_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9830_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9831_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9832_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9833_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9834_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9835_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9836_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9837_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9838_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9839_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/983_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9840_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9841_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9842_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9843_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9844_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9845_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9846_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9847_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9848_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9849_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/984_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9850_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9851_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9852_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9853_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9854_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9855_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9856_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9857_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9858_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9859_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/985_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9860_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9861_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9862_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9863_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9864_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9865_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9866_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9867_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9868_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9869_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/986_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9870_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9871_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9872_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9873_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9874_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9875_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9876_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9877_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9878_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9879_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/987_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9880_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9881_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9882_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9883_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9884_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9885_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9886_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9887_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9888_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9889_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/988_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9890_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9891_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9892_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9893_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9894_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9895_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9896_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9897_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9898_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9899_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/989_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/98_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9900_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9901_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9902_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9903_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9904_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9905_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9906_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9907_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9908_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9909_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/990_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9910_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9911_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9912_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9913_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9914_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9915_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9916_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9917_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9918_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9919_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/991_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9920_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9921_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9922_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9923_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9924_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9925_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9926_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9927_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9928_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9929_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/992_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9930_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9931_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9932_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9933_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9934_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9935_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9936_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9937_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9938_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9939_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/993_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9940_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9941_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9942_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9943_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9944_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9945_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9946_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9947_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9948_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9949_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/994_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9950_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9951_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9952_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9953_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9954_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9955_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9956_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9957_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9958_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9959_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/995_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9960_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9961_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9962_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9963_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9964_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9965_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9966_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9967_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9968_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9969_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/996_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9970_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9971_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9972_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9973_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9974_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9975_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9976_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9977_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9978_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9979_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/997_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9980_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9981_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9982_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9983_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9984_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9985_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9986_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9987_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9988_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9989_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/998_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9990_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9991_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9992_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9993_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9994_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9995_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9996_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9997_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9998_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9999_2004.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/999_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/99_2000.jpg
#   inflating: /content/sample_data/monet/monet_tfrec/images/9_2000.jpg

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from torchvision.utils import save_image
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
import torchvision
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from tqdm.notebook import tqdm
import math
import os
from glob import glob

# %%
DIR = '/content/sample_data/monet'
image_size = 128
batch_size = 256
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
transform = transforms.Compose([
    transforms.Resize(image_size),  # Đảm bảo kích thước đồng nhất
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize(*stats)
])
# Create a Dataset object using your image directory and transforms
dataset = torchvision.datasets.ImageFolder(
    DIR,
    transform=transform
)

# Create a DataLoader object to load batches of data
train_dataset = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=3,
    pin_memory=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
def denorm(img):
    return img* stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=49):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_xticks([]); ax.set_yticks([])
    imd = denorm(images.detach()[:nmax])
    ax.imshow(make_grid(imd, nrow=7).permute(1, 2, 0))

def show_batch(dl, nmax=49):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dataset)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device

# %%
train_dl = DeviceDataLoader(train_dataset, device)

# %%
discriminator = nn.Sequential(
    # in: 3 x 128 x 128

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 64 x 64

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 32 x 32

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 16 x 16

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 8 x 8

    nn.Conv2d(512, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Flatten(),
    nn.Linear(512 * 4 * 4, 200),
    nn.LeakyReLU(0.2, inplace=True),

    # Sigmoid activation for classification
    nn.Linear(200, 1),
    nn.Sigmoid()
)

# %%
discriminator = to_device(discriminator, device)

# %%
num_parameters = sum(p.numel() for p in discriminator.parameters())
print("Number of parameters:", num_parameters)

# %%
latent_size = 160

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 8 x 8

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 16 x 16

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 32 x 32

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 64 x 64

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 128 x 128
)

# %%
num_parameters = sum(p.numel() for p in generator.parameters())
print("Number of parameters:", num_parameters)

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()

    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()

    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)

    # Update generator weights
    loss.backward()
    opt_g.step()

    return loss.item()

# %%
sample_dir = 'generated'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    fake_images = generator(latent_tensors.to(device))
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname),nrow=7)
    print('Saving', fake_fname)

    if show:
        fig, ax = plt.subplots(figsize=(10, 10))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=7).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(49, latent_size, 1, 1).to(device)

# %%
save_samples(0, fixed_latent)

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()

    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []

    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))

    for epoch in range(epochs):
        for real_images, _ in tqdm(train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)

        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)

        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))

        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)

    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.001
epochs = 20

# %%
history = fit(epochs, lr)

# %%
losses_g, losses_d, real_scores, fake_scores = history
torch.save(generator.state_dict(), 'G.pth')
torch.save(discriminator.state_dict(), 'D.pth')

# %%
from IPython.display import Image

# %%
Image('./generated/generated-images-0001.png')

# %%
Image('./generated/generated-images-0020.png')

# %%
plt.plot(losses_d, '-')
plt.plot(losses_g, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');
